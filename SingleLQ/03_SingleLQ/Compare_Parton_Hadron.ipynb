# %%
import os
from ROOT import *
from glob import glob
# Out:
# Welcome to JupyROOT 6.25/01

# %%
gStyle.SetOptStat(0)
# !pwd
# Out:
# /mnt/Data/MadFolder/lq_mzp500_mlq500_2

# %%
inputDir1=os.getcwd()+"/SingleLQ_parton.root"
inputDir2=os.getcwd()+"/SingleLQ_hadron.root"

# %%
f1=TFile.Open(inputDir1)
f2=TFile.Open(inputDir2)

# %%
histlist1=f1.Get("histlist")
histlist2=f2.Get("histlist")

# %%
histlist1.Print()
# Out:
# Collection name='TList', class='TList', size=58
#  TH1.Print Name  = cutflow, Entries= 6820594, Total sum= 974.371
#  TH1.Print Name  = Number of jets, Entries= 700000, Total sum= 700000
#  TH1.Print Name  = hist_m_LQ, Entries= 670099, Total sum= 666072
#  TH1.Print Name  = hist_pt_LQ, Entries= 670099, Total sum= 670088
#  TH1.Print Name  = hist_m_LQ_met, Entries= 670099, Total sum= 666072
#  TH1.Print Name  = hist_pt_LQ_met, Entries= 670099, Total sum= 670088
#  TH1.Print Name  = hist_met, Entries= 670099, Total sum= 670099
#  TH1.Print Name  = pt_all_jets, Entries= 2680396, Total sum= 2.62344e+06
#  TH1.Print Name  = p_all_jets, Entries= 2680396, Total sum= 2.07991e+06
#  TH1.Print Name  = eta_all_jets, Entries= 2680396, Total sum= 2.6804e+06
#  TH1.Print Name  = pt_lead_jets, Entries= 670099, Total sum= 665586
#  TH1.Print Name  = p_lead_jets, Entries= 670099, Total sum= 419750
#  TH1.Print Name  = eta_lead_jets, Entries= 670099, Total sum= 670099
# ...

# %%
i=0
c1 = TCanvas( "c"+str(i), 'Example',700, 500)
c1.SetGrid()
histname='cutflow'
A=histlist1.FindObject(histname)
A.SetLineColor(kBlue)
#A.Scale(1./A.Integral())
#A.DrawNormalized("hist")
B=histlist2.FindObject(histname)
B.SetLineColor(8)
#B.Scale(1./B.Integral())
#B.DrawNormalized("histsame")
rp = TRatioPlot(B,A)
rp.Draw()
leg=TLegend(0.9,0.9,0.65,0.70)
leg.AddEntry(A, "Parton_Level", "l")
leg.AddEntry(B, "Hadron_Level", "l")
leg.Draw()
c1.Draw()

# %%
i+=1
c1 = TCanvas( "c"+str(i), 'Example',700, 500)
#c1.SetGrid()
histname='Number of jets'
A=histlist1.FindObject(histname)
A.SetLineColor(kBlue)
A.Scale(1./A.Integral())
A.DrawNormalized("hist")
B=histlist2.FindObject(histname)
B.SetLineColor(kRed)
B.Scale(1./B.Integral())
B.DrawNormalized("histsame")
rp = TRatioPlot(A,B)
#rp.Draw()
leg=TLegend(0.9,0.9,0.65,0.70)
leg.AddEntry(A, "Parton_Level", "l")
leg.AddEntry(B, "Hadron_Level", "l")
leg.Draw()
c1.Draw()

# %%
i+=1
c1 = TCanvas( "c"+str(i), 'Example',1200, 1200)
c1.SetGrid()
c1.Divide(2,2)
c1.cd(1)
histname='pt_lead_jets'
A=histlist1.FindObject(histname)
A.SetLineColor(kBlue)
A.Scale(1./A.Integral())

B=histlist2.FindObject(histname)
B.SetLineColor(kRed)
B.Scale(1./B.Integral())

B.DrawNormalized("hist")
A.DrawNormalized("histsame")

#rp = TRatioPlot(B,A)
#rp.Draw()
leg1=TLegend(0.9,0.9,0.65,0.70)
leg1.AddEntry(A, "Parton_Level", "l")
leg1.AddEntry(B, "Hadron_Level", "l")
leg1.Draw()

c1.cd(2)
histname='pt_lead_bjets'
A=histlist1.FindObject(histname)
A.SetLineColor(kBlue)
A.Scale(1./A.Integral())

B=histlist2.FindObject(histname)
B.SetLineColor(kRed)
B.Scale(1./B.Integral())

B.DrawNormalized("hist")
A.DrawNormalized("histsame")

#rp = TRatioPlot(B,A)
#rp.Draw()
leg2=TLegend(0.9,0.9,0.65,0.70)
leg2.AddEntry(A, "Parton_Level", "l")
leg2.AddEntry(B, "Hadron_Level", "l")
leg2.Draw()

c1.cd(3)
histname='pt_lead_taus'
A=histlist1.FindObject(histname)
A.SetLineColor(kBlue)
A.Scale(1./A.Integral())

B=histlist2.FindObject(histname)
B.SetLineColor(kRed)
B.Scale(1./B.Integral())

B.DrawNormalized("hist")
A.DrawNormalized("histsame")

#rp = TRatioPlot(B,A)
#rp.Draw()
leg3=TLegend(0.9,0.9,0.65,0.70)
leg3.AddEntry(A, "Parton_Level", "l")
leg3.AddEntry(B, "Hadron_Level", "l")
leg3.Draw()

c1.cd(4)
histname='pt_slead_taus'
A=histlist1.FindObject(histname)
A.SetLineColor(kBlue)
A.Scale(1./A.Integral())

B=histlist2.FindObject(histname)
B.SetLineColor(kRed)
B.Scale(1./B.Integral())

B.Draw("hist")
A.Draw("histsame")

#rp = TRatioPlot(B,A)
#rp.Draw()
leg4=TLegend(0.9,0.9,0.65,0.70)
leg4.AddEntry(A, "Parton_Level", "l")
leg4.AddEntry(B, "Hadron_Level", "l")
leg4.Draw()

c1.Draw()

# %%
i+=1
c1 = TCanvas( "c"+str(i), 'Example',1200, 1200)
c1.SetGrid()
c1.Divide(2,2)
c1.cd(1)
histname='p_lead_jets'
A=histlist1.FindObject(histname)
A.SetLineColor(kBlue)
A.Scale(1./A.Integral())

B=histlist2.FindObject(histname)
B.SetLineColor(kRed)
B.Scale(1./B.Integral())

B.DrawNormalized("hist")
A.DrawNormalized("histsame")

#rp = TRatioPlot(B,A)
#rp.Draw()
leg1=TLegend(0.9,0.9,0.65,0.70)
leg1.AddEntry(A, "Parton_Level", "l")
leg1.AddEntry(B, "Hadron_Level", "l")
leg1.Draw()

c1.cd(2)
histname='p_lead_bjets'
A=histlist1.FindObject(histname)
A.SetLineColor(kBlue)
A.Scale(1./A.Integral())

B=histlist2.FindObject(histname)
B.SetLineColor(kRed)
B.Scale(1./B.Integral())

B.DrawNormalized("hist")
A.DrawNormalized("histsame")

#rp = TRatioPlot(B,A)
#rp.Draw()
leg2=TLegend(0.9,0.9,0.65,0.70)
leg2.AddEntry(A, "Parton_Level", "l")
leg2.AddEntry(B, "Hadron_Level", "l")
leg2.Draw()

c1.cd(3)
histname='p_lead_taus'
A=histlist1.FindObject(histname)
A.SetLineColor(kBlue)
A.Scale(1./A.Integral())

B=histlist2.FindObject(histname)
B.SetLineColor(kRed)
B.Scale(1./B.Integral())

B.DrawNormalized("hist")
A.DrawNormalized("histsame")

#rp = TRatioPlot(B,A)
#rp.Draw()
leg3=TLegend(0.9,0.9,0.65,0.70)
leg3.AddEntry(A, "Parton_Level", "l")
leg3.AddEntry(B, "Hadron_Level", "l")
leg3.Draw()

c1.cd(4)
histname='p_slead_taus'
A=histlist1.FindObject(histname)
A.SetLineColor(kBlue)
A.Scale(1./A.Integral())

B=histlist2.FindObject(histname)
B.SetLineColor(kRed)
B.Scale(1./B.Integral())

B.Draw("hist")
A.Draw("histsame")

#rp = TRatioPlot(B,A)
#rp.Draw()
leg4=TLegend(0.9,0.9,0.65,0.70)
leg4.AddEntry(A, "Parton_Level", "l")
leg4.AddEntry(B, "Hadron_Level", "l")
leg4.Draw()

c1.Draw()

# %%
i+=1
c1 = TCanvas( "c"+str(i), 'Example',1200, 1200)
c1.SetGrid()
c1.Divide(2,2)
c1.cd(1)
histname='eta_lead_jets'
A=histlist1.FindObject(histname)
A.SetLineColor(kBlue)
A.Scale(1./A.Integral())

B=histlist2.FindObject(histname)
B.SetLineColor(kRed)
B.Scale(1./B.Integral())

B.DrawNormalized("hist")
A.DrawNormalized("histsame")

#rp = TRatioPlot(B,A)
#rp.Draw()
leg1=TLegend(0.9,0.9,0.65,0.70)
leg1.AddEntry(A, "Parton_Level", "l")
leg1.AddEntry(B, "Hadron_Level", "l")
leg1.Draw()

c1.cd(2)
histname='eta_lead_bjets'
A=histlist1.FindObject(histname)
A.SetLineColor(kBlue)
A.Scale(1./A.Integral())

B=histlist2.FindObject(histname)
B.SetLineColor(kRed)
B.Scale(1./B.Integral())

B.DrawNormalized("hist")
A.DrawNormalized("histsame")

#rp = TRatioPlot(B,A)
#rp.Draw()
leg2=TLegend(0.9,0.9,0.65,0.70)
leg2.AddEntry(A, "Parton_Level", "l")
leg2.AddEntry(B, "Hadron_Level", "l")
leg2.Draw()

c1.cd(3)
histname='eta_lead_taus'
A=histlist1.FindObject(histname)
A.SetLineColor(kBlue)
A.Scale(1./A.Integral())

B=histlist2.FindObject(histname)
B.SetLineColor(kRed)
B.Scale(1./B.Integral())

B.DrawNormalized("hist")
A.DrawNormalized("histsame")

#rp = TRatioPlot(B,A)
#rp.Draw()
leg3=TLegend(0.9,0.9,0.65,0.70)
leg3.AddEntry(A, "Parton_Level", "l")
leg3.AddEntry(B, "Hadron_Level", "l")
leg3.Draw()

c1.cd(4)
histname='eta_slead_taus'
A=histlist1.FindObject(histname)
A.SetLineColor(kBlue)
A.Scale(1./A.Integral())

B=histlist2.FindObject(histname)
B.SetLineColor(kRed)
B.Scale(1./B.Integral())

B.Draw("hist")
A.Draw("histsame")

#rp = TRatioPlot(B,A)
#rp.Draw()
leg4=TLegend(0.9,0.9,0.65,0.70)
leg4.AddEntry(A, "Parton_Level", "l")
leg4.AddEntry(B, "Hadron_Level", "l")
leg4.Draw()

c1.Draw()

# %%
i+=1
c1 = TCanvas( "c"+str(i), 'Example',1200, 1200)
c1.SetGrid()
c1.Divide(2,3)
c1.cd(1)
histname='hist_m_LQ'
A=histlist1.FindObject(histname)
A.SetLineColor(kBlue)
A.Scale(1./A.Integral())

B=histlist2.FindObject(histname)
B.SetLineColor(kRed)
B.Scale(1./B.Integral())

B.DrawNormalized("hist")
A.DrawNormalized("histsame")

#rp = TRatioPlot(B,A)
#rp.Draw()
leg1=TLegend(0.9,0.9,0.65,0.70)
leg1.AddEntry(A, "Parton_Level", "l")
leg1.AddEntry(B, "Hadron_Level", "l")
leg1.Draw()

c1.cd(2)
histname='hist_m_LQ_met'
A=histlist1.FindObject(histname)
A.SetLineColor(kBlue)
A.Scale(1./A.Integral())

B=histlist2.FindObject(histname)
B.SetLineColor(kRed)
B.Scale(1./B.Integral())

A.DrawNormalized("hist")
B.DrawNormalized("histsame")

#rp = TRatioPlot(B,A)
#rp.Draw()
leg2=TLegend(0.9,0.9,0.65,0.70)
leg2.AddEntry(A, "Parton_Level", "l")
leg2.AddEntry(B, "Hadron_Level", "l")
leg2.Draw()

c1.cd(3)
histname='hist_pt_LQ'
A=histlist1.FindObject(histname)
A.SetLineColor(kBlue)
A.Scale(1./A.Integral())

B=histlist2.FindObject(histname)
B.SetLineColor(kRed)
B.Scale(1./B.Integral())

B.DrawNormalized("hist")
A.DrawNormalized("histsame")

#rp = TRatioPlot(B,A)
#rp.Draw()
leg3=TLegend(0.9,0.9,0.65,0.70)
leg3.AddEntry(A, "Parton_Level", "l")
leg3.AddEntry(B, "Hadron_Level", "l")
leg3.Draw()

c1.cd(4)
histname='hist_pt_LQ_met'
A=histlist1.FindObject(histname)
A.SetLineColor(kBlue)
A.Scale(1./A.Integral())

B=histlist2.FindObject(histname)
B.SetLineColor(kRed)
B.Scale(1./B.Integral())

B.Draw("hist")
A.Draw("histsame")

#rp = TRatioPlot(B,A)
#rp.Draw()
leg4=TLegend(0.9,0.9,0.65,0.70)
leg4.AddEntry(A, "Parton_Level", "l")
leg4.AddEntry(B, "Hadron_Level", "l")
leg4.Draw()

c1.cd(5)
histname='hist_met'
A=histlist1.FindObject(histname)
A.SetLineColor(kBlue)
A.Scale(1./A.Integral())

B=histlist2.FindObject(histname)
B.SetLineColor(kRed)
B.Scale(1./B.Integral())

B.Draw("hist")
A.Draw("histsame")

#rp = TRatioPlot(B,A)
#rp.Draw()
leg4=TLegend(0.9,0.9,0.65,0.70)
leg4.AddEntry(A, "Parton_Level", "l")
leg4.AddEntry(B, "Hadron_Level", "l")
leg4.Draw()

c1.Draw()

# %%
i+=1
c1 = TCanvas( "c"+str(i), 'Example',1200, 1200)
c1.SetGrid()

c1.Divide(2,3)
c1.cd(1)
histname='deltaEta_b_j'
A=histlist1.FindObject(histname)
A.SetLineColor(kBlue)
A.Scale(1./A.Integral())

B=histlist2.FindObject(histname)
B.SetLineColor(kRed)
B.Scale(1./B.Integral())

B.DrawNormalized("hist")
A.DrawNormalized("histsame")

#rp = TRatioPlot(B,A)
#rp.Draw()
leg1=TLegend(0.9,0.9,0.65,0.70)
leg1.AddEntry(A, "Parton_Level", "l")
leg1.AddEntry(B, "Hadron_Level", "l")
leg1.Draw()

c1.cd(2)
histname='deltaPhi_b_j'
A=histlist1.FindObject(histname)
A.SetLineColor(kBlue)
A.Scale(1./A.Integral())

B=histlist2.FindObject(histname)
B.SetLineColor(kRed)
B.Scale(1./B.Integral())

B.DrawNormalized("hist")
A.DrawNormalized("histsame")

#rp = TRatioPlot(B,A)
#rp.Draw()
leg2=TLegend(0.9,0.9,0.65,0.70)
leg2.AddEntry(A, "Parton_Level", "l")
leg2.AddEntry(B, "Hadron_Level", "l")
leg2.Draw()

c1.cd(3)
histname='deltar_b_j'
A=histlist1.FindObject(histname)
A.SetLineColor(kBlue)
A.Scale(1./A.Integral())

B=histlist2.FindObject(histname)
B.SetLineColor(kRed)
B.Scale(1./B.Integral())

B.DrawNormalized("hist")
A.DrawNormalized("histsame")

#rp = TRatioPlot(B,A)
#rp.Draw()
leg3=TLegend(0.9,0.9,0.65,0.70)
leg3.AddEntry(A, "Parton_Level", "l")
leg3.AddEntry(B, "Hadron_Level", "l")
leg3.Draw()

c1.cd(4)
histname='sdPT_b_j'
A=histlist1.FindObject(histname)
A.SetLineColor(kBlue)
A.Scale(1./A.Integral())

B=histlist2.FindObject(histname)
B.SetLineColor(kRed)
B.Scale(1./B.Integral())

B.Draw("hist")
A.Draw("histsame")

#rp = TRatioPlot(B,A)
#rp.Draw()
leg4=TLegend(0.9,0.9,0.65,0.70)
leg4.AddEntry(A, "Parton_Level", "l")
leg4.AddEntry(B, "Hadron_Level", "l")
leg4.Draw()



c1.cd(5)
histname='vdPT_b_j'
A=histlist1.FindObject(histname)
A.SetLineColor(kBlue)
A.Scale(1./A.Integral())

B=histlist2.FindObject(histname)
B.SetLineColor(kRed)
B.Scale(1./B.Integral())

B.Draw("hist")
A.Draw("histsame")

#rp = TRatioPlot(B,A)
#rp.Draw()
leg5=TLegend(0.9,0.9,0.65,0.70)
leg5.AddEntry(A, "Parton_Level", "l")
leg5.AddEntry(B, "Hadron_Level", "l")
leg5.Draw()

c1.cd(6)
histname='vdP_b_j'
A=histlist1.FindObject(histname)
A.SetLineColor(kBlue)
A.Scale(1./A.Integral())

B=histlist2.FindObject(histname)
B.SetLineColor(kRed)
B.Scale(1./B.Integral())

B.Draw("hist")
A.Draw("histsame")

#rp = TRatioPlot(B,A)
#rp.Draw()
leg6=TLegend(0.9,0.9,0.65,0.70)
leg6.AddEntry(A, "Parton_Level", "l")
leg6.AddEntry(B, "Hadron_Level", "l")
leg6.Draw()

c1.Draw()

# %%
i+=1
c1 = TCanvas( "c"+str(i), 'Example',1200, 1200)
c1.SetGrid()

c1.Divide(2,3)
c1.cd(1)
histname='deltaEta_b_sltau'
A=histlist1.FindObject(histname)
A.SetLineColor(kBlue)
A.Scale(1./A.Integral())

B=histlist2.FindObject(histname)
B.SetLineColor(kRed)
B.Scale(1./B.Integral())

B.DrawNormalized("hist")
A.DrawNormalized("histsame")

#rp = TRatioPlot(B,A)
#rp.Draw()
leg1=TLegend(0.9,0.9,0.65,0.70)
leg1.AddEntry(A, "Parton_Level", "l")
leg1.AddEntry(B, "Hadron_Level", "l")
leg1.Draw()

c1.cd(2)
histname='deltaPhi_b_sltau'
A=histlist1.FindObject(histname)
A.SetLineColor(kBlue)
A.Scale(1./A.Integral())

B=histlist2.FindObject(histname)
B.SetLineColor(kRed)
B.Scale(1./B.Integral())

B.DrawNormalized("hist")
A.DrawNormalized("histsame")

#rp = TRatioPlot(B,A)
#rp.Draw()
leg2=TLegend(0.9,0.9,0.65,0.70)
leg2.AddEntry(A, "Parton_Level", "l")
leg2.AddEntry(B, "Hadron_Level", "l")
leg2.Draw()

c1.cd(3)
histname='deltar_b_sltau'
A=histlist1.FindObject(histname)
A.SetLineColor(kBlue)
A.Scale(1./A.Integral())

B=histlist2.FindObject(histname)
B.SetLineColor(kRed)
B.Scale(1./B.Integral())

B.DrawNormalized("hist")
A.DrawNormalized("histsame")

#rp = TRatioPlot(B,A)
#rp.Draw()
leg3=TLegend(0.9,0.9,0.65,0.70)
leg3.AddEntry(A, "Parton_Level", "l")
leg3.AddEntry(B, "Hadron_Level", "l")
leg3.Draw()

c1.cd(4)
histname='sdPT_b_sltau'
A=histlist1.FindObject(histname)
A.SetLineColor(kBlue)
A.Scale(1./A.Integral())

B=histlist2.FindObject(histname)
B.SetLineColor(kRed)
B.Scale(1./B.Integral())

B.Draw("hist")
A.Draw("histsame")

#rp = TRatioPlot(B,A)
#rp.Draw()
leg4=TLegend(0.9,0.9,0.65,0.70)
leg4.AddEntry(A, "Parton_Level", "l")
leg4.AddEntry(B, "Hadron_Level", "l")
leg4.Draw()



c1.cd(5)
histname='vdPT_b_sltau'
A=histlist1.FindObject(histname)
A.SetLineColor(kBlue)
A.Scale(1./A.Integral())

B=histlist2.FindObject(histname)
B.SetLineColor(kRed)
B.Scale(1./B.Integral())

B.Draw("hist")
A.Draw("histsame")

#rp = TRatioPlot(B,A)
#rp.Draw()
leg5=TLegend(0.9,0.9,0.65,0.70)
leg5.AddEntry(A, "Parton_Level", "l")
leg5.AddEntry(B, "Hadron_Level", "l")
leg5.Draw()

c1.cd(6)
histname='vdP_b_sltau'
A=histlist1.FindObject(histname)
A.SetLineColor(kBlue)
A.Scale(1./A.Integral())

B=histlist2.FindObject(histname)
B.SetLineColor(kRed)
B.Scale(1./B.Integral())

B.Draw("hist")
A.Draw("histsame")

#rp = TRatioPlot(B,A)
#rp.Draw()
leg6=TLegend(0.9,0.9,0.65,0.70)
leg6.AddEntry(A, "Parton_Level", "l")
leg6.AddEntry(B, "Hadron_Level", "l")
leg6.Draw()

c1.Draw()

# %%
i+=1
c1 = TCanvas( "c"+str(i), 'Example',1200, 1200)
c1.SetGrid()

c1.Divide(2,3)
c1.cd(1)
histname='deltaEta_taus'
A=histlist1.FindObject(histname)
A.SetLineColor(kBlue)
A.Scale(1./A.Integral())

B=histlist2.FindObject(histname)
B.SetLineColor(kRed)
B.Scale(1./B.Integral())

B.DrawNormalized("hist")
A.DrawNormalized("histsame")

#rp = TRatioPlot(B,A)
#rp.Draw()
leg1=TLegend(0.9,0.9,0.65,0.70)
leg1.AddEntry(A, "Parton_Level", "l")
leg1.AddEntry(B, "Hadron_Level", "l")
leg1.Draw()

c1.cd(2)
histname='deltaPhi_taus'
A=histlist1.FindObject(histname)
A.SetLineColor(kBlue)
A.Scale(1./A.Integral())

B=histlist2.FindObject(histname)
B.SetLineColor(kRed)
B.Scale(1./B.Integral())

B.DrawNormalized("hist")
A.DrawNormalized("histsame")

#rp = TRatioPlot(B,A)
#rp.Draw()
leg2=TLegend(0.9,0.9,0.65,0.70)
leg2.AddEntry(A, "Parton_Level", "l")
leg2.AddEntry(B, "Hadron_Level", "l")
leg2.Draw()

c1.cd(3)
histname='deta_taus'
A=histlist1.FindObject(histname)
A.SetLineColor(kBlue)
A.Scale(1./A.Integral())

B=histlist2.FindObject(histname)
B.SetLineColor(kRed)
B.Scale(1./B.Integral())

B.DrawNormalized("hist")
A.DrawNormalized("histsame")

#rp = TRatioPlot(B,A)
#rp.Draw()
leg3=TLegend(0.9,0.9,0.65,0.70)
leg3.AddEntry(A, "Parton_Level", "l")
leg3.AddEntry(B, "Hadron_Level", "l")
leg3.Draw()

c1.cd(4)
histname='sdPT_taus'
A=histlist1.FindObject(histname)
A.SetLineColor(kBlue)
A.Scale(1./A.Integral())

B=histlist2.FindObject(histname)
B.SetLineColor(kRed)
B.Scale(1./B.Integral())

B.Draw("hist")
A.Draw("histsame")

#rp = TRatioPlot(B,A)
#rp.Draw()
leg4=TLegend(0.9,0.9,0.65,0.70)
leg4.AddEntry(A, "Parton_Level", "l")
leg4.AddEntry(B, "Hadron_Level", "l")
leg4.Draw()



c1.cd(5)
histname='vdPT_taus'
A=histlist1.FindObject(histname)
A.SetLineColor(kBlue)
A.Scale(1./A.Integral())

B=histlist2.FindObject(histname)
B.SetLineColor(kRed)
B.Scale(1./B.Integral())

B.Draw("hist")
A.Draw("histsame")

#rp = TRatioPlot(B,A)
#rp.Draw()
leg5=TLegend(0.9,0.9,0.65,0.70)
leg5.AddEntry(A, "Parton_Level", "l")
leg5.AddEntry(B, "Hadron_Level", "l")
leg5.Draw()

c1.cd(6)
histname='vdP_taus'
A=histlist1.FindObject(histname)
A.SetLineColor(kBlue)
A.Scale(1./A.Integral())

B=histlist2.FindObject(histname)
B.SetLineColor(kRed)
B.Scale(1./B.Integral())

B.Draw("hist")
A.Draw("histsame")

#rp = TRatioPlot(B,A)
#rp.Draw()
leg6=TLegend(0.9,0.9,0.65,0.70)
leg6.AddEntry(A, "Parton_Level", "l")
leg6.AddEntry(B, "Hadron_Level", "l")
leg6.Draw()

c1.Draw()

# %%
i+=1
c1 = TCanvas( "c"+str(i), 'Example',1200, 1200)
c1.SetGrid()

c1.Divide(2,3)
c1.cd(1)
histname='deltaEta_j_ltau'
A=histlist1.FindObject(histname)
A.SetLineColor(kBlue)
A.Scale(1./A.Integral())

B=histlist2.FindObject(histname)
B.SetLineColor(kRed)
B.Scale(1./B.Integral())

B.DrawNormalized("hist")
A.DrawNormalized("histsame")

#rp = TRatioPlot(B,A)
#rp.Draw()
leg1=TLegend(0.9,0.9,0.65,0.70)
leg1.AddEntry(A, "Parton_Level", "l")
leg1.AddEntry(B, "Hadron_Level", "l")
leg1.Draw()

c1.cd(2)
histname='deltaPhi_j_ltau'
A=histlist1.FindObject(histname)
A.SetLineColor(kBlue)
A.Scale(1./A.Integral())

B=histlist2.FindObject(histname)
B.SetLineColor(kRed)
B.Scale(1./B.Integral())

B.DrawNormalized("hist")
A.DrawNormalized("histsame")

#rp = TRatioPlot(B,A)
#rp.Draw()
leg2=TLegend(0.9,0.9,0.65,0.70)
leg2.AddEntry(A, "Parton_Level", "l")
leg2.AddEntry(B, "Hadron_Level", "l")
leg2.Draw()

c1.cd(3)
histname='deltar_j_ltau'
A=histlist1.FindObject(histname)
A.SetLineColor(kBlue)
A.Scale(1./A.Integral())

B=histlist2.FindObject(histname)
B.SetLineColor(kRed)
B.Scale(1./B.Integral())

B.DrawNormalized("hist")
A.DrawNormalized("histsame")

#rp = TRatioPlot(B,A)
#rp.Draw()
leg3=TLegend(0.9,0.9,0.65,0.70)
leg3.AddEntry(A, "Parton_Level", "l")
leg3.AddEntry(B, "Hadron_Level", "l")
leg3.Draw()

c1.cd(4)
histname='sdPT_j_ltau'
A=histlist1.FindObject(histname)
A.SetLineColor(kBlue)
A.Scale(1./A.Integral())

B=histlist2.FindObject(histname)
B.SetLineColor(kRed)
B.Scale(1./B.Integral())

B.Draw("hist")
A.Draw("histsame")

#rp = TRatioPlot(B,A)
#rp.Draw()
leg4=TLegend(0.9,0.9,0.65,0.70)
leg4.AddEntry(A, "Parton_Level", "l")
leg4.AddEntry(B, "Hadron_Level", "l")
leg4.Draw()



c1.cd(5)
histname='vdPT_j_ltau'
A=histlist1.FindObject(histname)
A.SetLineColor(kBlue)
A.Scale(1./A.Integral())

B=histlist2.FindObject(histname)
B.SetLineColor(kRed)
B.Scale(1./B.Integral())

B.Draw("hist")
A.Draw("histsame")

#rp = TRatioPlot(B,A)
#rp.Draw()
leg5=TLegend(0.9,0.9,0.65,0.70)
leg5.AddEntry(A, "Parton_Level", "l")
leg5.AddEntry(B, "Hadron_Level", "l")
leg5.Draw()

c1.cd(6)
histname='vdP_j_ltau'
A=histlist1.FindObject(histname)
A.SetLineColor(kBlue)
A.Scale(1./A.Integral())

B=histlist2.FindObject(histname)
B.SetLineColor(kRed)
B.Scale(1./B.Integral())

B.Draw("hist")
A.Draw("histsame")

#rp = TRatioPlot(B,A)
#rp.Draw()
leg6=TLegend(0.9,0.9,0.65,0.70)
leg6.AddEntry(A, "Parton_Level", "l")
leg6.AddEntry(B, "Hadron_Level", "l")
leg6.Draw()

c1.Draw()

# %%
i+=1
c1 = TCanvas( "c"+str(i), 'Example',1200, 1200)
c1.SetGrid()

c1.Divide(2,3)
c1.cd(1)
histname='deltaEta_j_sltau'
A=histlist1.FindObject(histname)
A.SetLineColor(kBlue)
A.Scale(1./A.Integral())

B=histlist2.FindObject(histname)
B.SetLineColor(kRed)
B.Scale(1./B.Integral())

B.DrawNormalized("hist")
A.DrawNormalized("histsame")

#rp = TRatioPlot(B,A)
#rp.Draw()
leg1=TLegend(0.9,0.9,0.65,0.70)
leg1.AddEntry(A, "Parton_Level", "l")
leg1.AddEntry(B, "Hadron_Level", "l")
leg1.Draw()

c1.cd(2)
histname='deltaPhi_j_sltau'
A=histlist1.FindObject(histname)
A.SetLineColor(kBlue)
A.Scale(1./A.Integral())

B=histlist2.FindObject(histname)
B.SetLineColor(kRed)
B.Scale(1./B.Integral())

B.DrawNormalized("hist")
A.DrawNormalized("histsame")

#rp = TRatioPlot(B,A)
#rp.Draw()
leg2=TLegend(0.9,0.9,0.65,0.70)
leg2.AddEntry(A, "Parton_Level", "l")
leg2.AddEntry(B, "Hadron_Level", "l")
leg2.Draw()

c1.cd(3)
histname='deltar_j_sltau'
A=histlist1.FindObject(histname)
A.SetLineColor(kBlue)
A.Scale(1./A.Integral())

B=histlist2.FindObject(histname)
B.SetLineColor(kRed)
B.Scale(1./B.Integral())

B.DrawNormalized("hist")
A.DrawNormalized("histsame")

#rp = TRatioPlot(B,A)
#rp.Draw()
leg3=TLegend(0.9,0.9,0.65,0.70)
leg3.AddEntry(A, "Parton_Level", "l")
leg3.AddEntry(B, "Hadron_Level", "l")
leg3.Draw()

c1.cd(4)
histname='sdPT_j_sltau'
A=histlist1.FindObject(histname)
A.SetLineColor(kBlue)
A.Scale(1./A.Integral())

B=histlist2.FindObject(histname)
B.SetLineColor(kRed)
B.Scale(1./B.Integral())

B.Draw("hist")
A.Draw("histsame")

#rp = TRatioPlot(B,A)
#rp.Draw()
leg4=TLegend(0.9,0.9,0.65,0.70)
leg4.AddEntry(A, "Parton_Level", "l")
leg4.AddEntry(B, "Hadron_Level", "l")
leg4.Draw()



c1.cd(5)
histname='vdPT_j_sltau'
A=histlist1.FindObject(histname)
A.SetLineColor(kBlue)
A.Scale(1./A.Integral())

B=histlist2.FindObject(histname)
B.SetLineColor(kRed)
B.Scale(1./B.Integral())

B.Draw("hist")
A.Draw("histsame")

#rp = TRatioPlot(B,A)
#rp.Draw()
leg5=TLegend(0.9,0.9,0.65,0.70)
leg5.AddEntry(A, "Parton_Level", "l")
leg5.AddEntry(B, "Hadron_Level", "l")
leg5.Draw()

c1.cd(6)
histname='vdP_j_sltau'
A=histlist1.FindObject(histname)
A.SetLineColor(kBlue)
A.Scale(1./A.Integral())

B=histlist2.FindObject(histname)
B.SetLineColor(kRed)
B.Scale(1./B.Integral())

B.Draw("hist")
A.Draw("histsame")

#rp = TRatioPlot(B,A)
#rp.Draw()
leg6=TLegend(0.9,0.9,0.65,0.70)
leg6.AddEntry(A, "Parton_Level", "l")
leg6.AddEntry(B, "Hadron_Level", "l")
leg6.Draw()

c1.Draw()

# %%
i+=1
c1 = TCanvas( "c"+str(i), 'Example',1200, 1200)
c1.SetGrid()

c1.Divide(2,3)
c1.cd(1)
histname='deltaEta_b_ltau'
A=histlist1.FindObject(histname)
A.SetLineColor(kBlue)
A.Scale(1./A.Integral())

B=histlist2.FindObject(histname)
B.SetLineColor(kRed)
B.Scale(1./B.Integral())

B.DrawNormalized("hist")
A.DrawNormalized("histsame")

#rp = TRatioPlot(B,A)
#rp.Draw()
leg1=TLegend(0.9,0.9,0.65,0.70)
leg1.AddEntry(A, "Parton_Level", "l")
leg1.AddEntry(B, "Hadron_Level", "l")
leg1.Draw()

c1.cd(2)
histname='deltaPhi_b_ltau'
A=histlist1.FindObject(histname)
A.SetLineColor(kBlue)
A.Scale(1./A.Integral())

B=histlist2.FindObject(histname)
B.SetLineColor(kRed)
B.Scale(1./B.Integral())

B.DrawNormalized("hist")
A.DrawNormalized("histsame")

#rp = TRatioPlot(B,A)
#rp.Draw()
leg2=TLegend(0.9,0.9,0.65,0.70)
leg2.AddEntry(A, "Parton_Level", "l")
leg2.AddEntry(B, "Hadron_Level", "l")
leg2.Draw()

c1.cd(3)
histname='deltar_b_ltau'
A=histlist1.FindObject(histname)
A.SetLineColor(kBlue)
A.Scale(1./A.Integral())

B=histlist2.FindObject(histname)
B.SetLineColor(kRed)
B.Scale(1./B.Integral())

B.DrawNormalized("hist")
A.DrawNormalized("histsame")

#rp = TRatioPlot(B,A)
#rp.Draw()
leg3=TLegend(0.9,0.9,0.65,0.70)
leg3.AddEntry(A, "Parton_Level", "l")
leg3.AddEntry(B, "Hadron_Level", "l")
leg3.Draw()

c1.cd(4)
histname='sdPT_b_ltau'
A=histlist1.FindObject(histname)
A.SetLineColor(kBlue)
A.Scale(1./A.Integral())

B=histlist2.FindObject(histname)
B.SetLineColor(kRed)
B.Scale(1./B.Integral())

B.Draw("hist")
A.Draw("histsame")

#rp = TRatioPlot(B,A)
#rp.Draw()
leg4=TLegend(0.9,0.9,0.65,0.70)
leg4.AddEntry(A, "Parton_Level", "l")
leg4.AddEntry(B, "Hadron_Level", "l")
leg4.Draw()



c1.cd(5)
histname='vdPT_b_ltau'
A=histlist1.FindObject(histname)
A.SetLineColor(kBlue)
A.Scale(1./A.Integral())

B=histlist2.FindObject(histname)
B.SetLineColor(kRed)
B.Scale(1./B.Integral())

B.Draw("hist")
A.Draw("histsame")

#rp = TRatioPlot(B,A)
#rp.Draw()
leg5=TLegend(0.9,0.9,0.65,0.70)
leg5.AddEntry(A, "Parton_Level", "l")
leg5.AddEntry(B, "Hadron_Level", "l")
leg5.Draw()

c1.cd(6)
histname='vdP_b_ltau'
A=histlist1.FindObject(histname)
A.SetLineColor(kBlue)
A.Scale(1./A.Integral())

B=histlist2.FindObject(histname)
B.SetLineColor(kRed)
B.Scale(1./B.Integral())

A.Draw("hist")
B.Draw("histsame")

#rp = TRatioPlot(B,A)
#rp.Draw()
leg6=TLegend(0.9,0.9,0.65,0.70)
leg6.AddEntry(A, "Parton_Level", "l")
leg6.AddEntry(B, "Hadron_Level", "l")
leg6.Draw()

c1.Draw()
